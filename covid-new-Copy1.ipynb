# %%
from BayesNet import BayesNet
from BNReasoner import BNReasoner
import networkx as nx
import pandas as pd
import copy

# %%
#TD: If at some point you get a "omp Error #15," try running this code. It worked for me, but apparently it is not the best solution as it can cause problems, so use with "caution" I suppose 

import os 
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
covid = BayesNet()
covid.load_from_bifxml('testing/Use_Case.BIFXML')

# %%
covid.draw_structure()

# %%
covid.get_all_variables()
# Out:
# ['Cough?',
#  'Loss of smell?',
#  'Sore throat?',
#  'Positive PCR test?',
#  'Positive antigen test?',
#  'Covid-19?',
#  'Cold?',
#  'Cannot breathe?',
#  'High fever?',
#  'Take Ivermectin?',
#  'ICU?',
#  'Recovery?']

# %%
covid.get_all_cpts()
# Out:
# {'Cough?':    Cough?     p
#  0   False  0.95
#  1    True  0.05, 'Loss of smell?':    Loss of smell?     p
#  0           False  0.99
#  1            True  0.01, 'Sore throat?':    Sore throat?     p
#  0         False  0.98
#  1          True  0.02, 'Positive PCR test?':     Cough?  Loss of smell?  Sore throat?  Positive antigen test?  \
#  0    False           False         False                   False
#  1    False           False         False                   False
#  2    False           False         False                    True
#  3    False           False         False                    True
#  4    False           False          True                   False
#  5    False           False          True                   False
#  6    False           False          True                    True
#  7    False           False          True                    True
#  8    False            True         False                   False
#  9    False            True         False                   False
#  10   False            True         False                    True
#  11   False            True         False                    True
#  12   False            True          True                   False
#  13   False            True          True                   False
#  14   False            True          True                    True
#  15   False            True          True                    True
#  16    True           False         False                   False
#  17    True           False         False                   False
#  18    True           False         False                    True
#  19    True           False         False                    True
#  20    True           False          True                   False
#  21    True           False          True                   False
#  22    True           False          True                    True
#  23    True           False          True                    True
#  24    True            True         False                   False
#  25    True            True         False                   False
#  26    True            True         False                    True
#  27    True            True         False                    True
#  28    True            True          True                   False
#  29    True            True          True                   False
#  30    True            True          True                    True
#  31    True            True          True                    True
#
#      Positive PCR test?      p
#  0                False  0.989
#  1                 True  0.011
#  2                False  0.030
#  3                 True  0.970
#  4                False  0.980
#  5                 True  0.020
#  6                False  0.030
#  7                 True  0.970
#  8                False  0.100
#  9                 True  0.900
#  10               False  0.060
#  11                True  0.940
#  12               False  0.050
#  13                True  0.950
#  14               False  0.050
#  15                True  0.950
#  16               False  0.040
#  17                True  0.960
#  18               False  0.020
#  19                True  0.980
#  20               False  0.100
#  21                True  0.900
#  22               False  0.020
#  23                True  0.980
#  24               False  0.950
#  25                True  0.050
#  26               False  0.080
#  27                True  0.920
#  28               False  0.950
#  29                True  0.050
#  30               False  0.011
#  31                True  0.989  , 'Positive antigen test?':     Cough?  Loss of smell?  Sore throat?  Positive antigen test?      p
#  0    False           False         False                   False  0.976
#  1    False           False         False                    True  0.024
#  2    False           False          True                   False  0.100
#  3    False           False          True                    True  0.900
#  4    False            True         False                   False  0.865
#  5    False            True         False                    True  0.135
#  6    False            True          True                   False  0.860
#  7    False            True          True                    True  0.140
#  8     True           False         False                   False  0.100
#  9     True           False         False                    True  0.900
#  10    True           False          True                   False  0.890
#  11    True           False          True                    True  0.110
#  12    True            True         False                   False  0.860
#  13    True            True         False                    True  0.140
#  14    True            True          True                   False  0.850
#  15    True            True          True                    True  0.150, 'Covid-19?':    Positive PCR test?  Positive antigen test?  Covid-19?      p
#  0               False                   False      False  0.985
#  1               False                   False       True  0.015
#  2               False                    True      False  0.200
#  3               False                    True       True  0.800
#  4                True                   False      False  0.250
#  5                True                   False       True  0.750
#  6                True                    True      False  0.100
#  7                True                    True       True  0.900, 'Cold?':    Positive antigen test?  Positive PCR test?  Cold?      p
#  0                   False               False  False  0.950
#  1                   False               False   True  0.050
#  2                   False                True  False  0.990
#  3                   False                True   True  0.100
#  4                    True               False  False  0.985
#  5                    True               False   True  0.015
#  6                    True                True  False  0.985
#  7                    True                True   True  0.015, 'Cannot breathe?':    Covid-19?  Cold?  Cannot breathe?       p
#  0      False  False            False  1.0000
#  1      False  False             True  0.0000
#  2      False   True            False  0.9995
#  3      False   True             True  0.0005
#  4       True  False            False  0.8500
#  5       True  False             True  0.1500
#  6       True   True            False  0.8000
#  7       True   True             True  0.2000, 'High fever?':    Covid-19?  Cold?  High fever?     p
#  0      False  False        False  1.00
#  1      False  False         True  0.00
#  2      False   True        False  0.95
#  3      False   True         True  0.05
#  4       True  False        False  0.70
#  5       True  False         True  0.30
#  6       True   True        False  0.55
#  7       True   True         True  0.45, 'Take Ivermectin?':    Covid-19?  Cold?  Take Ivermectin?      p
#  0      False  False             False  1.000
#  1      False  False              True  0.000
#  2      False   True             False  0.995
#  3      False   True              True  0.005
#  4       True  False             False  0.950
#  5       True  False              True  0.050
#  6       True   True             False  0.950
#  7       True   True              True  0.050, 'ICU?':     Cannot breathe?  High fever?  Take Ivermectin?   ICU?     p
#  0             False        False             False  False  1.00
#  1             False        False             False   True  0.00
#  2             False        False              True  False  0.70
#  3             False        False              True   True  0.30
#  4             False         True             False  False  0.60
#  5             False         True             False   True  0.40
#  6             False         True              True  False  0.50
#  7             False         True              True   True  0.50
#  8              True        False             False  False  0.40
#  9              True        False             False   True  0.60
#  10             True        False              True  False  0.30
#  11             True        False              True   True  0.70
#  12             True         True             False  False  0.20
#  13             True         True             False   True  0.80
#  14             True         True              True  False  0.15
#  15             True         True              True   True  0.85, 'Recovery?':     Cannot breathe?  High fever?  Take Ivermectin?   ICU?  Recovery?     p
#  0             False        False             False  False      False  0.00
#  1             False        False             False  False       True  1.00
#  2             False        False             False   True      False  0.10
#  3             False        False             False   True       True  0.90
#  4             False        False              True  False      False  0.95
#  5             False        False              True  False       True  0.05
#  6             False        False              True   True      False  0.15
#  7             False        False              True   True       True  0.85
#  8             False         True             False  False      False  0.05
#  9             False         True             False  False       True  0.95
#  10            False         True             False   True      False  0.30
#  11            False         True             False   True       True  0.70
#  12            False         True              True  False      False  0.10
#  13            False         True              True  False       True  0.90
#  14            False         True              True   True      False  0.30
#  15            False         True              True   True       True  0.70
#  16             True        False             False  False      False  0.10
#  17             True        False             False  False       True  0.90
#  18             True        False             False   True      False  0.25
#  19             True        False             False   True       True  0.75
#  20             True        False              True  False      False  0.10
#  21             True        False              True  False       True  0.90
#  22             True        False              True   True      False  0.40
#  23             True        False              True   True       True  0.60
#  24             True         True             False  False      False  0.25
#  25             True         True             False  False       True  0.75
#  26             True         True             False   True      False  0.55
#  27             True         True             False   True       True  0.45
#  28             True         True              True  False      False  0.30
#  29             True         True              True  False       True  0.70
#  30             True         True              True   True      False  0.60
#  31             True         True              True   True       True  0.40}

# %%
covid.get_children('ICU?')
# Out:
# ['Recovery?']

# %%
covid.get_all_edges()
# Out:
# [('Cough?', 'Positive PCR test?'),
#  ('Cough?', 'Positive antigen test?'),
#  ('Loss of smell?', 'Positive PCR test?'),
#  ('Loss of smell?', 'Positive antigen test?'),
#  ('Sore throat?', 'Positive PCR test?'),
#  ('Sore throat?', 'Positive antigen test?'),
#  ('Positive PCR test?', 'Cold?'),
#  ('Positive PCR test?', 'Covid-19?'),
#  ('Positive antigen test?', 'Positive PCR test?'),
#  ('Positive antigen test?', 'Cold?'),
#  ('Positive antigen test?', 'Covid-19?'),
#  ('Covid-19?', 'Take Ivermectin?'),
#  ('Covid-19?', 'High fever?'),
#  ('Covid-19?', 'Cannot breathe?'),
#  ('Cold?', 'Take Ivermectin?'),
#  ('Cold?', 'High fever?'),
#  ('Cold?', 'Cannot breathe?'),
#  ('Cannot breathe?', 'ICU?'),
#  ('Cannot breathe?', 'Recovery?'),
#  ('High fever?', 'ICU?'),
#  ('High fever?', 'Recovery?'),
#  ('Take Ivermectin?', 'ICU?'),
#  ('Take Ivermectin?', 'Recovery?'),
#  ('ICU?', 'Recovery?')]

# %% [markdown]
# ## a) d-separation

# %%
reasoner = BNReasoner(covid)

# %%
x = ['Sore throat?', 'Cold?']
y = ['Cough?', 'ICU?']
z = ['Take Ivermectin?']
reasoner.d_separation(x, y, z)
# Out:
# False

# %% [markdown]
# ## b) Ordering

# %%
print('Mindegree heuristic: ')
reasoner.ordering_mindegree(covid)
# Out:
# Mindegree heuristic:
# ['Cough?',
#  'Loss of smell?',
#  'Sore throat?',
#  'Positive PCR test?',
#  'Positive antigen test?',
#  'Covid-19?',
#  'Cold?',
#  'Cannot breathe?',
#  'High fever?',
#  'Take Ivermectin?',
#  'ICU?',
#  'Recovery?']

# %%
print('Minfill heuristic: ')

reasoner.ordering_minfill(covid)
# Out:
# Minfill heuristic:
# ['Cough?',
#  'Loss of smell?',
#  'Sore throat?',
#  'Positive PCR test?',
#  'Positive antigen test?',
#  'Covid-19?',
#  'Cold?',
#  'Cannot breathe?',
#  'High fever?',
#  'Take Ivermectin?',
#  'ICU?',
#  'Recovery?']

# %% [markdown]
# # c) Network Pruning

# %%
q = ['ICU?']
e = pd.Series({'Covid-19?': True, 'Cold?': False})

pruned = reasoner.net_prune(q, e)

# %%
pruned.get_cpt('ICU?')
# Out:
#     Cannot breathe?  High fever?  Take Ivermectin?   ICU?     p
# 0             False        False             False  False  1.00
# 1             False        False             False   True  0.00
# 2             False        False              True  False  0.70
# 3             False        False              True   True  0.30
# 4             False         True             False  False  0.60
# 5             False         True             False   True  0.40
# 6             False         True              True  False  0.50
# 7             False         True              True   True  0.50
# 8              True        False             False  False  0.40
# 9              True        False             False   True  0.60
# 10             True        False              True  False  0.30
# 11             True        False              True   True  0.70
# 12             True         True             False  False  0.20
# 13             True         True             False   True  0.80
# 14             True         True              True  False  0.15
# 15             True         True              True   True  0.85

# %% [markdown]
# ## d) Marginal distributions
#
# ### summing-out:

# %%
factor = covid.get_cpt('ICU?')
factor
# Out:
#     Cannot breathe?  High fever?  Take Ivermectin?   ICU?     p
# 0             False        False             False  False  1.00
# 1             False        False             False   True  0.00
# 2             False        False              True  False  0.70
# 3             False        False              True   True  0.30
# 4             False         True             False  False  0.60
# 5             False         True             False   True  0.40
# 6             False         True              True  False  0.50
# 7             False         True              True   True  0.50
# 8              True        False             False  False  0.40
# 9              True        False             False   True  0.60
# 10             True        False              True  False  0.30
# 11             True        False              True   True  0.70
# 12             True         True             False  False  0.20
# 13             True         True             False   True  0.80
# 14             True         True              True  False  0.15
# 15             True         True              True   True  0.85

# %%
reasoner.sum_out(factor, ['ICU?'])
# Out:
#    Cannot breathe?  High fever?  Take Ivermectin?    p
# 0            False        False             False  1.0
# 1            False        False              True  1.0
# 2            False         True             False  1.0
# 3            False         True              True  1.0
# 4             True        False             False  1.0
# 5             True        False              True  1.0
# 6             True         True             False  1.0
# 7             True         True              True  1.0

# %% [markdown]
# ### multiplying

# %%
hospital = covid.get_cpt('ICU?')
hospital
# Out:
#     Cannot breathe?  High fever?  Take Ivermectin?   ICU?     p
# 0             False        False             False  False  1.00
# 1             False        False             False   True  0.00
# 2             False        False              True  False  0.70
# 3             False        False              True   True  0.30
# 4             False         True             False  False  0.60
# 5             False         True             False   True  0.40
# 6             False         True              True  False  0.50
# 7             False         True              True   True  0.50
# 8              True        False             False  False  0.40
# 9              True        False             False   True  0.60
# 10             True        False              True  False  0.30
# 11             True        False              True   True  0.70
# 12             True         True             False  False  0.20
# 13             True         True             False   True  0.80
# 14             True         True              True  False  0.15
# 15             True         True              True   True  0.85

# %%
Joe_Rogan = covid.get_cpt('Take Ivermectin?')
Joe_Rogan
# Out:
#    Covid-19?  Cold?  Take Ivermectin?      p
# 0      False  False             False  1.000
# 1      False  False              True  0.000
# 2      False   True             False  0.995
# 3      False   True              True  0.005
# 4       True  False             False  0.950
# 5       True  False              True  0.050
# 6       True   True             False  0.950
# 7       True   True              True  0.050

# %%
hospital = covid.get_cpt('ICU?')
Joe_Rogan = covid.get_cpt('Take Ivermectin?')

# %%
reasoner.mult([Joe_Rogan, hospital])
# Out:
#     Covid-19?  Cold?  Take Ivermectin?  Cannot breathe?  High fever?   ICU?  \
# 0       False  False             False            False        False  False
# 1       False  False             False            False        False   True
# 2       False  False             False            False         True  False
# 3       False  False             False            False         True   True
# 4       False  False             False             True        False  False
# ..        ...    ...               ...              ...          ...    ...
# 59       True   True              True            False         True   True
# 60       True   True              True             True        False  False
# 61       True   True              True             True        False   True
# 62       True   True              True             True         True  False
# 63       True   True              True             True         True   True
#
#          p
# 0   1.0000
# 1   0.0000
# 2   0.6000
# 3   0.4000
# 4   0.4000
# ..     ...
# 59  0.0250
# 60  0.0150
# 61  0.0350
# 62  0.0075
# 63  0.0425
#
# [64 rows x 7 columns]

# %% [markdown]
# ### get marginal

# %%
evidence = pd.Series({"Cold?": False, "Sore throat?": False})
query_vars = ["Covid-19?"]

marginals = reasoner.get_marginal_distribution('random', query_vars, evidence)

# %%
marginals
# Out:
#   Covid-19?         p
# 0     False  0.908700
# 0      True  0.093304

# %% [markdown]
# ## MPE

# %%
reasoner.MPE('mindegree')
# Out:
# (          p Cough? Loss of smell? Sore throat? Positive PCR test?  \
#  0  0.832513  False          False        False              False
#
#    Positive antigen test? Covid-19?  Cold? Cannot breathe? High fever?  \
#  0                  False     False  False           False       False
#
#    Take Ivermectin?   ICU? Recovery?
#  0            False  False      True  , 1070, 0, 1070)

# %%
reasoner.MPE('minfill')
# Out:
# (          p Cough? Loss of smell? Sore throat? Positive PCR test?  \
#  0  0.832513  False          False        False              False
#
#    Positive antigen test? Covid-19?  Cold? Cannot breathe? High fever?  \
#  0                  False     False  False           False       False
#
#    Take Ivermectin?   ICU? Recovery?
#  0            False  False      True  , 1070, 0, 1070)

# %%
reasoner.MPE('random')
# Out:
# (          p Sore throat? Cough? Cannot breathe? Recovery?  Cold? High fever?  \
#  9  0.832513        False  False           False      True  False       False
#
#      ICU? Positive antigen test? Take Ivermectin? Loss of smell?  \
#  9  False                  False            False          False
#
#    Positive PCR test? Covid-19?
#  9              False     False  , 1089, 0, 1089)

# %%
reasoner.MAP('mindegree', map_vars = ['Covid-19?'], e_vars = evidence)
# Out:
# {'Cough?':    Cough?     p
# 0   False  0.95
# 1    True  0.05, 'Loss of smell?':    Loss of smell?     p
# 0           False  0.99
# 1            True  0.01, 'Sore throat?':    Sore throat?     p
# 0         False  0.98
# 1          True  0.02, 'Positive PCR test?':     Cough?  Loss of smell?  Positive antigen test?  Positive PCR test?      p
# 0    False           False                   False               False  0.989
# 1    False           False                   False                True  0.011
# 2    False           False                    True               False  0.030
# 3    False           False                    True                True  0.970
# 8    False            True                   False               False  0.100
# 9    False            True                   False                True  0.900
# 10   False            True                    True               False  0.060
# 11   False            True                    True                True  0.940
# 16    True           False                   False               False  0.040
# 17    True           False                   False                True  0.960
# 18    True           False                    True               False  0.020
# 19    True           False                    True                True  0.980
# 24    True            True                   False               False  0.950
# 25    True            True                   False                True  0.050
# 26    True            True                    True               False  0.080
# 27    True            True                    True                True  0.920, 'Positive antigen test?':     Cough?  Loss of smell?  Positive antigen test?      p
# 0    False           False                   False  0.976
# 1    False           False                    True  0.024
# 4    False            True                   False  0.865
# 5    False            True                    True  0.135
# 8     True           False                   False  0.100
# 9     True           False                    True  0.900
# 12    True            True                   False  0.860
# 13    True            True                    True  0.140, 'Covid-19?':    Positive PCR test?  Positive antigen test?  Covid-19?      p
# 0               False                   False      False  0.985
# 1               False                   False       True  0.015
# 2               False                    True      False  0.200
# 3               False                    True       True  0.800
# 4                True                   False      False  0.250
# 5                True                   False       True  0.750
# 6                True                    True      False  0.100
# 7                True                    True       True  0.900, 'Cold?':    Positive antigen test?  Positive PCR test?  Cold?      p
# 0                   False               False  False  0.950
# 1                   False               False   True  0.050
# 2                   False                True  False  0.990
# 3                   False                True   True  0.100
# 4                    True               False  False  0.985
# 5                    True               False   True  0.015
# 6                    True                True  False  0.985
# 7                    True                True   True  0.015}
# [   Sore throat?     p
# 0         False  0.98
# 1          True  0.02]
#      p
# 0  1.0
# [   Positive antigen test?  Positive PCR test?  Cold?      p
# 0                   False               False  False  0.950
# 1                   False               False   True  0.050
# 2                   False                True  False  0.990
# 3                   False                True   True  0.100
# 4                    True               False  False  0.985
# 5                    True               False   True  0.015
# 6                    True                True  False  0.985
# 7                    True                True   True  0.015]
#    Positive antigen test?  Positive PCR test?     p
# 0                   False               False  1.00
# 1                   False                True  1.09
# 2                    True               False  1.00
# 3                    True                True  1.00
# [   Cough?     p
# 0   False  0.95
# 1    True  0.05,     Cough?  Loss of smell?  Positive antigen test?  Positive PCR test?      p
# 0    False           False                   False               False  0.989
# 1    False           False                   False                True  0.011
# 2    False           False                    True               False  0.030
# 3    False           False                    True                True  0.970
# 8    False            True                   False               False  0.100
# 9    False            True                   False                True  0.900
# 10   False            True                    True               False  0.060
# 11   False            True                    True                True  0.940
# 16    True           False                   False               False  0.040
# 17    True           False                   False                True  0.960
# 18    True           False                    True               False  0.020
# 19    True           False                    True                True  0.980
# 24    True            True                   False               False  0.950
# 25    True            True                   False                True  0.050
# 26    True            True                    True               False  0.080
# 27    True            True                    True                True  0.920,     Cough?  Loss of smell?  Positive antigen test?      p
# 0    False           False                   False  0.976
# 1    False           False                    True  0.024
# 4    False            True                   False  0.865
# 5    False            True                    True  0.135
# 8     True           False                   False  0.100
# 9     True           False                    True  0.900
# 12    True            True                   False  0.860
# 13    True            True                    True  0.140]
#    Loss of smell?  Positive antigen test?  Positive PCR test?         p
# 0           False                   False               False  0.917201
# 1           False                   False                True  0.014999
# 2           False                    True               False  0.001584
# 3           False                    True                True  0.066216
# 4            True                   False               False  0.123025
# 5            True                   False                True  0.741725
# 6            True                    True               False  0.008255
# 7            True                    True                True  0.126995
# [   Loss of smell?     p
# 0           False  0.99
# 1            True  0.01,    Loss of smell?  Positive antigen test?  Positive PCR test?         p
# 0           False                   False               False  0.917201
# 1           False                   False                True  0.014999
# 2           False                    True               False  0.001584
# 3           False                    True                True  0.066216
# 4            True                   False               False  0.123025
# 5            True                   False                True  0.741725
# 6            True                    True               False  0.008255
# 7            True                    True                True  0.126995]
#    Positive antigen test?  Positive PCR test?         p
# 0                   False               False  0.909259
# 1                   False                True  0.022266
# 2                    True               False  0.001651
# 3                    True                True  0.066824
# [   Positive PCR test?  Positive antigen test?  Covid-19?      p
# 0               False                   False      False  0.985
# 1               False                   False       True  0.015
# 2               False                    True      False  0.200
# 3               False                    True       True  0.800
# 4                True                   False      False  0.250
# 5                True                   False       True  0.750
# 6                True                    True      False  0.100
# 7                True                    True       True  0.900,    Positive antigen test?  Positive PCR test?     p
# 0                   False               False  1.00
# 1                   False                True  1.09
# 2                    True               False  1.00
# 3                    True                True  1.00,    Positive antigen test?  Positive PCR test?         p
# 0                   False               False  0.909259
# 1                   False                True  0.022266
# 2                    True               False  0.001651
# 3                    True                True  0.066824]
#    Positive antigen test?  Covid-19?         p
# 0                   False      False  0.901688
# 1                   False       True  0.031842
# 2                    True      False  0.007013
# 3                    True       True  0.061462
# [   Positive antigen test?  Covid-19?         p
# 0                   False      False  0.901688
# 1                   False       True  0.031842
# 2                    True      False  0.007013
# 3                    True       True  0.061462]
#    Covid-19?         p
# 0      False  0.908700
# 1       True  0.093304
# [   Covid-19?         p
# 0      False  0.908700
# 1       True  0.093304]
#         p  Covid-19?
# 0  0.9087      False
# {'Sore throat?':      p
# 0  1.0, 'Covid-19?':         p  Covid-19?
# 0  0.9087      False}
#   Covid-19?       p
# 0     False  0.9087
# (  Covid-19?       p
#  0     False  0.9087, 48, 46, 2)

# %%
0.211838*0.09003
# Out:
# 0.01907177514

# %%
reasoner.MAP('minfill', map_vars = ['Covid-19?'])
# Out:
# {'Cough?':    Cough?     p
# 0   False  0.95
# 1    True  0.05, 'Loss of smell?':    Loss of smell?     p
# 0           False  0.99
# 1            True  0.01, 'Sore throat?':    Sore throat?     p
# 0         False  0.98
# 1          True  0.02, 'Positive PCR test?':     Cough?  Loss of smell?  Sore throat?  Positive antigen test?  \
# 0    False           False         False                   False
# 1    False           False         False                   False
# 2    False           False         False                    True
# 3    False           False         False                    True
# 4    False           False          True                   False
# 5    False           False          True                   False
# 6    False           False          True                    True
# 7    False           False          True                    True
# 8    False            True         False                   False
# 9    False            True         False                   False
# 10   False            True         False                    True
# 11   False            True         False                    True
# 12   False            True          True                   False
# 13   False            True          True                   False
# 14   False            True          True                    True
# 15   False            True          True                    True
# 16    True           False         False                   False
# 17    True           False         False                   False
# 18    True           False         False                    True
# 19    True           False         False                    True
# 20    True           False          True                   False
# 21    True           False          True                   False
# 22    True           False          True                    True
# 23    True           False          True                    True
# 24    True            True         False                   False
# 25    True            True         False                   False
# 26    True            True         False                    True
# 27    True            True         False                    True
# 28    True            True          True                   False
# 29    True            True          True                   False
# 30    True            True          True                    True
# 31    True            True          True                    True
#
#     Positive PCR test?      p
# 0                False  0.989
# 1                 True  0.011
# 2                False  0.030
# 3                 True  0.970
# 4                False  0.980
# 5                 True  0.020
# 6                False  0.030
# 7                 True  0.970
# 8                False  0.100
# 9                 True  0.900
# 10               False  0.060
# 11                True  0.940
# 12               False  0.050
# 13                True  0.950
# 14               False  0.050
# 15                True  0.950
# 16               False  0.040
# 17                True  0.960
# 18               False  0.020
# 19                True  0.980
# 20               False  0.100
# 21                True  0.900
# 22               False  0.020
# 23                True  0.980
# 24               False  0.950
# 25                True  0.050
# 26               False  0.080
# 27                True  0.920
# 28               False  0.950
# 29                True  0.050
# 30               False  0.011
# 31                True  0.989  , 'Positive antigen test?':     Cough?  Loss of smell?  Sore throat?  Positive antigen test?      p
# 0    False           False         False                   False  0.976
# 1    False           False         False                    True  0.024
# 2    False           False          True                   False  0.100
# 3    False           False          True                    True  0.900
# 4    False            True         False                   False  0.865
# 5    False            True         False                    True  0.135
# 6    False            True          True                   False  0.860
# 7    False            True          True                    True  0.140
# 8     True           False         False                   False  0.100
# 9     True           False         False                    True  0.900
# 10    True           False          True                   False  0.890
# 11    True           False          True                    True  0.110
# 12    True            True         False                   False  0.860
# 13    True            True         False                    True  0.140
# 14    True            True          True                   False  0.850
# 15    True            True          True                    True  0.150, 'Covid-19?':    Positive PCR test?  Positive antigen test?  Covid-19?      p
# 0               False                   False      False  0.985
# 1               False                   False       True  0.015
# 2               False                    True      False  0.200
# 3               False                    True       True  0.800
# 4                True                   False      False  0.250
# 5                True                   False       True  0.750
# 6                True                    True      False  0.100
# 7                True                    True       True  0.900}
# [   Cough?     p
# 0   False  0.95
# 1    True  0.05,     Cough?  Loss of smell?  Sore throat?  Positive antigen test?  \
# 0    False           False         False                   False
# 1    False           False         False                   False
# 2    False           False         False                    True
# 3    False           False         False                    True
# 4    False           False          True                   False
# 5    False           False          True                   False
# 6    False           False          True                    True
# 7    False           False          True                    True
# 8    False            True         False                   False
# 9    False            True         False                   False
# 10   False            True         False                    True
# 11   False            True         False                    True
# 12   False            True          True                   False
# 13   False            True          True                   False
# 14   False            True          True                    True
# 15   False            True          True                    True
# 16    True           False         False                   False
# 17    True           False         False                   False
# 18    True           False         False                    True
# 19    True           False         False                    True
# 20    True           False          True                   False
# 21    True           False          True                   False
# 22    True           False          True                    True
# 23    True           False          True                    True
# 24    True            True         False                   False
# 25    True            True         False                   False
# 26    True            True         False                    True
# 27    True            True         False                    True
# 28    True            True          True                   False
# 29    True            True          True                   False
# 30    True            True          True                    True
# 31    True            True          True                    True
#
#     Positive PCR test?      p
# 0                False  0.989
# 1                 True  0.011
# 2                False  0.030
# 3                 True  0.970
# 4                False  0.980
# 5                 True  0.020
# 6                False  0.030
# 7                 True  0.970
# 8                False  0.100
# 9                 True  0.900
# 10               False  0.060
# 11                True  0.940
# 12               False  0.050
# 13                True  0.950
# 14               False  0.050
# 15                True  0.950
# 16               False  0.040
# 17                True  0.960
# 18               False  0.020
# 19                True  0.980
# 20               False  0.100
# 21                True  0.900
# 22               False  0.020
# 23                True  0.980
# 24               False  0.950
# 25                True  0.050
# 26               False  0.080
# 27                True  0.920
# 28               False  0.950
# 29                True  0.050
# 30               False  0.011
# 31                True  0.989  ,     Cough?  Loss of smell?  Sore throat?  Positive antigen test?      p
# 0    False           False         False                   False  0.976
# 1    False           False         False                    True  0.024
# 2    False           False          True                   False  0.100
# 3    False           False          True                    True  0.900
# 4    False            True         False                   False  0.865
# 5    False            True         False                    True  0.135
# 6    False            True          True                   False  0.860
# 7    False            True          True                    True  0.140
# 8     True           False         False                   False  0.100
# 9     True           False         False                    True  0.900
# 10    True           False          True                   False  0.890
# 11    True           False          True                    True  0.110
# 12    True            True         False                   False  0.860
# 13    True            True         False                    True  0.140
# 14    True            True          True                   False  0.850
# 15    True            True          True                    True  0.150]
#     Loss of smell?  Sore throat?  Positive antigen test?  Positive PCR test?  \
# 0            False         False                   False               False
# 1            False         False                   False                True
# 2            False         False                    True               False
# 3            False         False                    True                True
# 4            False          True                   False               False
# 5            False          True                   False                True
# 6            False          True                    True               False
# 7            False          True                    True                True
# 8             True         False                   False               False
# 9             True         False                   False                True
# 10            True         False                    True               False
# 11            True         False                    True                True
# 12            True          True                   False               False
# 13            True          True                   False                True
# 14            True          True                    True               False
# 15            True          True                    True                True
#
#            p
# 0   0.917201
# 1   0.014999
# 2   0.001584
# 3   0.066216
# 4   0.097550
# 5   0.041950
# 6   0.025760
# 7   0.834740
# 8   0.123025
# 9   0.741725
# 10  0.008255
# 11  0.126995
# 12  0.081225
# 13  0.778275
# 14  0.006733
# 15  0.133768
# [   Loss of smell?     p
# 0           False  0.99
# 1            True  0.01,     Loss of smell?  Sore throat?  Positive antigen test?  Positive PCR test?  \
# 0            False         False                   False               False
# 1            False         False                   False                True
# 2            False         False                    True               False
# 3            False         False                    True                True
# 4            False          True                   False               False
# 5            False          True                   False                True
# 6            False          True                    True               False
# 7            False          True                    True                True
# 8             True         False                   False               False
# 9             True         False                   False                True
# 10            True         False                    True               False
# 11            True         False                    True                True
# 12            True          True                   False               False
# 13            True          True                   False                True
# 14            True          True                    True               False
# 15            True          True                    True                True
#
#            p
# 0   0.917201
# 1   0.014999
# 2   0.001584
# 3   0.066216
# 4   0.097550
# 5   0.041950
# 6   0.025760
# 7   0.834740
# 8   0.123025
# 9   0.741725
# 10  0.008255
# 11  0.126995
# 12  0.081225
# 13  0.778275
# 14  0.006733
# 15  0.133768  ]
#    Sore throat?  Positive antigen test?  Positive PCR test?         p
# 0         False                   False               False  0.909259
# 1         False                   False                True  0.022266
# 2         False                    True               False  0.001651
# 3         False                    True                True  0.066824
# 4          True                   False               False  0.097387
# 5          True                   False                True  0.049313
# 6          True                    True               False  0.025570
# 7          True                    True                True  0.827730
# [   Sore throat?     p
# 0         False  0.98
# 1          True  0.02,    Sore throat?  Positive antigen test?  Positive PCR test?         p
# 0         False                   False               False  0.909259
# 1         False                   False                True  0.022266
# 2         False                    True               False  0.001651
# 3         False                    True                True  0.066824
# 4          True                   False               False  0.097387
# 5          True                   False                True  0.049313
# 6          True                    True               False  0.025570
# 7          True                    True                True  0.827730]
#    Positive antigen test?  Positive PCR test?         p
# 0                   False               False  0.893022
# 1                   False                True  0.022807
# 2                    True               False  0.002129
# 3                    True                True  0.082042
# [   Positive PCR test?  Positive antigen test?  Covid-19?      p
# 0               False                   False      False  0.985
# 1               False                   False       True  0.015
# 2               False                    True      False  0.200
# 3               False                    True       True  0.800
# 4                True                   False      False  0.250
# 5                True                   False       True  0.750
# 6                True                    True      False  0.100
# 7                True                    True       True  0.900,    Positive antigen test?  Positive PCR test?         p
# 0                   False               False  0.893022
# 1                   False                True  0.022807
# 2                    True               False  0.002129
# 3                    True                True  0.082042]
#    Positive antigen test?  Covid-19?         p
# 0                   False      False  0.885328
# 1                   False       True  0.030501
# 2                    True      False  0.008630
# 3                    True       True  0.075541
# [   Positive antigen test?  Covid-19?         p
# 0                   False      False  0.885328
# 1                   False       True  0.030501
# 2                    True      False  0.008630
# 3                    True       True  0.075541]
#    Covid-19?         p
# 0      False  0.893958
# 1       True  0.106042
# [   Covid-19?         p
# 0      False  0.893958
# 1       True  0.106042]
#           p  Covid-19?
# 0  0.893958      False
# {'Covid-19?':           p  Covid-19?
# 0  0.893958      False}
#           p  Covid-19?
# 0  0.893958      False
# (          p  Covid-19?
#  0  0.893958      False, 70, 68, 2)

# %%
reasoner.MAP('random', map_vars = ['Covid-19?'])
# Out:
# {'Cough?':    Cough?     p
# 0   False  0.95
# 1    True  0.05, 'Loss of smell?':    Loss of smell?     p
# 0           False  0.99
# 1            True  0.01, 'Sore throat?':    Sore throat?     p
# 0         False  0.98
# 1          True  0.02, 'Positive PCR test?':     Cough?  Loss of smell?  Sore throat?  Positive antigen test?  \
# 0    False           False         False                   False
# 1    False           False         False                   False
# 2    False           False         False                    True
# 3    False           False         False                    True
# 4    False           False          True                   False
# 5    False           False          True                   False
# 6    False           False          True                    True
# 7    False           False          True                    True
# 8    False            True         False                   False
# 9    False            True         False                   False
# 10   False            True         False                    True
# 11   False            True         False                    True
# 12   False            True          True                   False
# 13   False            True          True                   False
# 14   False            True          True                    True
# 15   False            True          True                    True
# 16    True           False         False                   False
# 17    True           False         False                   False
# 18    True           False         False                    True
# 19    True           False         False                    True
# 20    True           False          True                   False
# 21    True           False          True                   False
# 22    True           False          True                    True
# 23    True           False          True                    True
# 24    True            True         False                   False
# 25    True            True         False                   False
# 26    True            True         False                    True
# 27    True            True         False                    True
# 28    True            True          True                   False
# 29    True            True          True                   False
# 30    True            True          True                    True
# 31    True            True          True                    True
#
#     Positive PCR test?      p
# 0                False  0.989
# 1                 True  0.011
# 2                False  0.030
# 3                 True  0.970
# 4                False  0.980
# 5                 True  0.020
# 6                False  0.030
# 7                 True  0.970
# 8                False  0.100
# 9                 True  0.900
# 10               False  0.060
# 11                True  0.940
# 12               False  0.050
# 13                True  0.950
# 14               False  0.050
# 15                True  0.950
# 16               False  0.040
# 17                True  0.960
# 18               False  0.020
# 19                True  0.980
# 20               False  0.100
# 21                True  0.900
# 22               False  0.020
# 23                True  0.980
# 24               False  0.950
# 25                True  0.050
# 26               False  0.080
# 27                True  0.920
# 28               False  0.950
# 29                True  0.050
# 30               False  0.011
# 31                True  0.989  , 'Positive antigen test?':     Cough?  Loss of smell?  Sore throat?  Positive antigen test?      p
# 0    False           False         False                   False  0.976
# 1    False           False         False                    True  0.024
# 2    False           False          True                   False  0.100
# 3    False           False          True                    True  0.900
# 4    False            True         False                   False  0.865
# 5    False            True         False                    True  0.135
# 6    False            True          True                   False  0.860
# 7    False            True          True                    True  0.140
# 8     True           False         False                   False  0.100
# 9     True           False         False                    True  0.900
# 10    True           False          True                   False  0.890
# 11    True           False          True                    True  0.110
# 12    True            True         False                   False  0.860
# 13    True            True         False                    True  0.140
# 14    True            True          True                   False  0.850
# 15    True            True          True                    True  0.150, 'Covid-19?':    Positive PCR test?  Positive antigen test?  Covid-19?      p
# 0               False                   False      False  0.985
# 1               False                   False       True  0.015
# 2               False                    True      False  0.200
# 3               False                    True       True  0.800
# 4                True                   False      False  0.250
# 5                True                   False       True  0.750
# 6                True                    True      False  0.100
# 7                True                    True       True  0.900}
# [   Loss of smell?     p
# 0           False  0.99
# 1            True  0.01,     Cough?  Loss of smell?  Sore throat?  Positive antigen test?  \
# 0    False           False         False                   False
# 1    False           False         False                   False
# 2    False           False         False                    True
# 3    False           False         False                    True
# 4    False           False          True                   False
# 5    False           False          True                   False
# 6    False           False          True                    True
# 7    False           False          True                    True
# 8    False            True         False                   False
# 9    False            True         False                   False
# 10   False            True         False                    True
# 11   False            True         False                    True
# 12   False            True          True                   False
# 13   False            True          True                   False
# 14   False            True          True                    True
# 15   False            True          True                    True
# 16    True           False         False                   False
# 17    True           False         False                   False
# 18    True           False         False                    True
# 19    True           False         False                    True
# 20    True           False          True                   False
# 21    True           False          True                   False
# 22    True           False          True                    True
# 23    True           False          True                    True
# 24    True            True         False                   False
# 25    True            True         False                   False
# 26    True            True         False                    True
# 27    True            True         False                    True
# 28    True            True          True                   False
# 29    True            True          True                   False
# 30    True            True          True                    True
# 31    True            True          True                    True
#
#     Positive PCR test?      p
# 0                False  0.989
# 1                 True  0.011
# 2                False  0.030
# 3                 True  0.970
# 4                False  0.980
# 5                 True  0.020
# 6                False  0.030
# 7                 True  0.970
# 8                False  0.100
# 9                 True  0.900
# 10               False  0.060
# 11                True  0.940
# 12               False  0.050
# 13                True  0.950
# 14               False  0.050
# 15                True  0.950
# 16               False  0.040
# 17                True  0.960
# 18               False  0.020
# 19                True  0.980
# 20               False  0.100
# 21                True  0.900
# 22               False  0.020
# 23                True  0.980
# 24               False  0.950
# 25                True  0.050
# 26               False  0.080
# 27                True  0.920
# 28               False  0.950
# 29                True  0.050
# 30               False  0.011
# 31                True  0.989  ,     Cough?  Loss of smell?  Sore throat?  Positive antigen test?      p
# 0    False           False         False                   False  0.976
# 1    False           False         False                    True  0.024
# 2    False           False          True                   False  0.100
# 3    False           False          True                    True  0.900
# 4    False            True         False                   False  0.865
# 5    False            True         False                    True  0.135
# 6    False            True          True                   False  0.860
# 7    False            True          True                    True  0.140
# 8     True           False         False                   False  0.100
# 9     True           False         False                    True  0.900
# 10    True           False          True                   False  0.890
# 11    True           False          True                    True  0.110
# 12    True            True         False                   False  0.860
# 13    True            True         False                    True  0.140
# 14    True            True          True                   False  0.850
# 15    True            True          True                    True  0.150]
#     Cough?  Sore throat?  Positive antigen test?  Positive PCR test?         p
# 0    False         False                   False               False  0.956476
# 1    False         False                   False                True  0.018414
# 2    False         False                    True               False  0.000794
# 3    False         False                    True                True  0.024316
# 4    False          True                   False               False  0.097450
# 5    False          True                   False                True  0.010150
# 6    False          True                    True               False  0.026800
# 7    False          True                    True                True  0.865600
# 8     True         False                   False               False  0.012130
# 9     True         False                   False                True  0.095470
# 10    True         False                    True               False  0.017932
# 11    True         False                    True                True  0.874468
# 12    True          True                   False               False  0.096185
# 13    True          True                   False                True  0.793415
# 14    True          True                    True               False  0.002195
# 15    True          True                    True                True  0.108205
# [   Cough?     p
# 0   False  0.95
# 1    True  0.05,     Cough?  Sore throat?  Positive antigen test?  Positive PCR test?         p
# 0    False         False                   False               False  0.956476
# 1    False         False                   False                True  0.018414
# 2    False         False                    True               False  0.000794
# 3    False         False                    True                True  0.024316
# 4    False          True                   False               False  0.097450
# 5    False          True                   False                True  0.010150
# 6    False          True                    True               False  0.026800
# 7    False          True                    True                True  0.865600
# 8     True         False                   False               False  0.012130
# 9     True         False                   False                True  0.095470
# 10    True         False                    True               False  0.017932
# 11    True         False                    True                True  0.874468
# 12    True          True                   False               False  0.096185
# 13    True          True                   False                True  0.793415
# 14    True          True                    True               False  0.002195
# 15    True          True                    True                True  0.108205]
#    Sore throat?  Positive antigen test?  Positive PCR test?         p
# 0         False                   False               False  0.909259
# 1         False                   False                True  0.022266
# 2         False                    True               False  0.001651
# 3         False                    True                True  0.066824
# 4          True                   False               False  0.097387
# 5          True                   False                True  0.049313
# 6          True                    True               False  0.025570
# 7          True                    True                True  0.827730
# [   Sore throat?     p
# 0         False  0.98
# 1          True  0.02,    Sore throat?  Positive antigen test?  Positive PCR test?         p
# 0         False                   False               False  0.909259
# 1         False                   False                True  0.022266
# 2         False                    True               False  0.001651
# 3         False                    True                True  0.066824
# 4          True                   False               False  0.097387
# 5          True                   False                True  0.049313
# 6          True                    True               False  0.025570
# 7          True                    True                True  0.827730]
#    Positive antigen test?  Positive PCR test?         p
# 0                   False               False  0.893022
# 1                   False                True  0.022807
# 2                    True               False  0.002129
# 3                    True                True  0.082042
# [   Positive PCR test?  Positive antigen test?  Covid-19?      p
# 0               False                   False      False  0.985
# 1               False                   False       True  0.015
# 2               False                    True      False  0.200
# 3               False                    True       True  0.800
# 4                True                   False      False  0.250
# 5                True                   False       True  0.750
# 6                True                    True      False  0.100
# 7                True                    True       True  0.900,    Positive antigen test?  Positive PCR test?         p
# 0                   False               False  0.893022
# 1                   False                True  0.022807
# 2                    True               False  0.002129
# 3                    True                True  0.082042]
#    Positive PCR test?  Covid-19?         p
# 0               False      False  0.880052
# 1               False       True  0.015099
# 2                True      False  0.013906
# 3                True       True  0.090943
# [   Positive PCR test?  Covid-19?         p
# 0               False      False  0.880052
# 1               False       True  0.015099
# 2                True      False  0.013906
# 3                True       True  0.090943]
#    Covid-19?         p
# 0      False  0.893958
# 1       True  0.106042
# [   Covid-19?         p
# 0      False  0.893958
# 1       True  0.106042]
#           p  Covid-19?
# 0  0.893958      False
# {'Covid-19?':           p  Covid-19?
# 0  0.893958      False}
#           p  Covid-19?
# 0  0.893958      False
# (          p  Covid-19?
#  0  0.893958      False, 70, 68, 2)
